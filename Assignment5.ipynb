# %% [markdown]
# #Assignment 5

# %% [markdown]
# ##1. 클래스와 모듈의 공통점과 차이점에 대해 설명하시오.

# %% [markdown]
# 공통점 : 둘 모두 새로운 공간을 생성하여 그 안 소스를 작성할 수 있다.
#
# 차이점 : 모듈은 파일 단위, 클래스는 클래스 영역 내에 공간을 구성한다.

# %% [markdown]
# ##2. 다형성에 대해 설명하고 다형성을 보여주는 자신만의 파이썬 코드 예제를 제시하시오.

# %% [markdown]
# 다형성이란 서로 다른 유형의 객체들에 대하여 같은 구문을 사용하는 능력을 말하며 프로그램 작성 코드 량이 줄어들어 가독성을 높이는 장점이 있다.

# %%
class game:
    def kind(self):
        print "Unknowen"

class Diablo(game):
    def kind(self):
        print "RPG"

class Hearthstone(game):
    def kind(self):
        print "TCG"

class heroesofthestorm(game):
    def kind(self):
        print "AOS"
        
class mobile(game):
    pass
        
for x in (Diablo(),Hearthstone(),heroesofthestorm(),mobile()):
    x.kind()
# Out:
# RPG
# TCG
# AOS
# Unknowen

# %% [markdown]
# ##3. 다음 각 요구사항 모두를 만족시키는 Counter 클래스를 코딩하시오 (정답을 각 요구사항별로 입력할 필요 없이 3번 문제에 대해 1개의 클래스 정의 코드를 제시하면 된다.)
#
# •요구사항 1. 생성자에 count 값과 step 값을 인자로 받을 수 있다.
#
# ◾count: Counter 인스턴스가 지니는 초기 정수 값
#
# ◾step: Counter 인스턴스의 count가 증가되는 증분 (defalt 값: 1)
#
# c = Counter(10)
#
# d = Counter(10, 2)
#
# •요구사항 2. 다음과 같이 Counter의 인스턴스를 출력을 해주는 __str__() 메소드를 Counter 클래스 내에 구현하시오.
#
#  print c
#
#  [Count (step: 1)] 10
#  print d
#
#  [Count (step: 2)] 10
#
# •요구사항 3. 다음과 같이 step에 주어진 증분만큼 count를 증가시키는 incr() 메소드를 Counter 클래스 내에 구현하시오.
#
#  c.incr()
#
#  d.incr()
#
# print c
#
#  [Count (step: 1)] 11
#
#  print d
#
#  [Count (step: 2)] 12
#
# •요구사항 4. Counter 클래스 내에 관련 메소드를 추가하여 인스턴스 객체를 직접 호출(call)할 수 있도록 하시오. 인스턴스 객체를 직접 호출했을 때에 내부적으로 incr() 메소드를 호출하는 방법으로 구현하시오.
#
#  c()
#
#  d()
#
#  print c
#
#  [Count (step: 1)] 12
#
# print d
#
#  [Count (step: 2)] 14
#
#
# •요구사항 5. 다음과 같은 두 개의 산술 연산 (+, -)이 수행될 수 있도록 Counter 클래스 내에 관련 메소드를 추가하시오.
#
# c = c + 5
#
#  d = d - 5
#
#  print c
#
#  [Count (step: 1)] 17
#
#  print d
#
#  [Count (step: 2)] 9
#
# •요구사항 6. 다음과 같은 관계연산 (>, <, ==)이 수행될 수 있도록 Counter 클래스 내에 관련 메소드를 추가하시오.
#
#  print c > 10
#
#  True
#
#  print d > 10
#
#  False
#
#  print c < 10
#
#  False
#
#  print d < 10
#
#  True
#
#  print c == 17
#
#  True
#
#  print d != 9
#
#  False

# %%
class Counter:
    def __init__(self, c, s=1):
        self.count = c
        self.step = s
        self.incr()
    def __str__(self):
        return "[Count(step:"+str(self.step)+")]"+str(self.count)
    def incr(self):
        self.count += self.step
    def __add__(self, other):
        return self.count + other
    def __sub__(self, other):
        return self.count - other
    def __lt__(self, other):
        return self.count < other
    def __le__(self, other):
        return self.count <= other
    def __eq__(self, other):
        return self.count == other
    def __ne__(self, other):
        return self.count != other
    def __gt__(self, other):
        return self.count > other
    def __ge__(self, other):
        return self.count >= other
    
a = Counter(10,3)

print a
print a < 11
print a > 11
print a == 11
print a != 11
print a >= 11
print a <= 11
# Out:
# [Count(step:3)]13
# False
# True
# False
# True
# True
# False

# %% [markdown]
# ##4. 다음은 내장 자료형 list를 서브클래싱하여 만든 MySet 클래스 정의 내용이다. 다음 클래스 정의에서 __init__(), __str()__(), elimicate_duplicate()의 세 개의 메소드 코드 내용을 자신이 다른 사람에게 가르친다고 생각하며 설명해보시오.
# •MySet은 집합(Set) 자료형을 정의하려는 의도하에 만들어진 클래스이다.

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)

    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print s
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print t
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}

# %% [markdown]
# Myset 클래스는 리스트를 집합화 시켜주는 클래스로 init()는 생성자이며 클래스를 선언하면 자동으로 실행되어지는 함수로써 list형태의 자료를 입력받아서 클래스내 인스턴스 변수에 입력받은 리스트를 저장하는 역할을 합니다. 다음으로 str()는 출력함수로 기본 pirnt 구문으로 불려질 때에 리스트를 그냥 출력하는 것이 아닌 Myset :{,,,}형태로 출력되도록 해주는 함수입니다. 마지막으로 eliminate_duplicate()함수는 이 클래스의 가장 주된 기능을 하는 함수로써 리스트에서 중복되는 값을 없애는 역할을 수행합니다. 리스트를 for구문으로 새로운 인스턴스 리스트에 입력받은 리스트를 넣되 이미 들어가 있는지를 검사하여 없을 경우에만 새로운 인스턴스 리스트에 값을 저장하여 중복되는 값을 제외시켜 결과적으로 집합의 특징인 중복이 없게 되어진 리스트를 반환시켜줍니다.

# %% [markdown]
# ##5. 4번 문제에 정의된 MySet 클래스에 메소드를 추가하여 다음 각 요구사항 모두를 만족시키는 코딩을 제시하시오
# •정답을 각 요구사항별로 입력할 필요 없이 요구사항 3개 전체에 대해 1개의 MySet 클래스 정의 코드를 제시하고 주석등으로 해당 코드를 설명한다.
#
# •요구사항 1. | 연산으로 두 집합의 합집합을 반환한다.
#
#  u = s | t
#
# print u
#
#  MySet: {1, 2, 3, 4, 5, 6, 7, 8, 9}
#
#
#
# •요구사항 2. & 연산으로 두 집합의 교집합을 반환한다.
#
#
#  u = s & t
#
#  print u
#
#  MySet: {2, 3}
#
#
#
# •요구사항 3. - 연산으로 두 집합의 차집합을 반환한다.
#
#
#  s = MySet([1, 2, 3])
#
#  t = MySet([3, 4, 5])
#
#  u = s - t
#
# print u
#
#  MySet: {1}

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result
    
    def __or__(self, other):
        sub = []
        for x in self:
            sub.append(x)
        for x in other:
            if x not in sub:
                sub.append(x)
        return MySet(sub)
        
    def __and__(self, other):
        common = []
        for x in other:
            if x in self:
                common.append(x)
        return MySet(common)
    
    def __sub__(self, other):
        diff = []
        for x in self:
            if x not in other:
                diff.append(x)
        return MySet(diff)


    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)

    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print s
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print t
    u = s | t 
    print u 
    v = s & t 
    print v
    w = s - t 
    print w
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}
# MySet: {1 ,2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}
# MySet: {2 ,3}
# MySet: {1}

# %% [markdown]
# ##6. 5번 문제에서 정의한 MySet 클래스에 대해 다음 예제를 수행하면 오류없이 올바르게 동작하는 것을 확인할 수 있다. 다음 예제 내에 있는 len(), bool() 내장함수와 in 키워드 사용 예제가 별다른 메소드 정의를 하지 않았는 데도 올바르게 수행되는 이유를 설명하시오.
# > \>\>\> s = MySet([1, 2, 3, 4, 5, 6])  <br/>
# > \>\>\> print len(s)  <br/>
# > 6 <br/>
# > \>\>\> print bool(s)  <br/>
# > True <br/>
# > \>\>\> print 2 in s  <br/>
# > True <br/>

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result
    
    def __or__(self, other):
        sub = []
        for x in self:
            sub.append(x)
        for x in other:
            if x not in sub:
                sub.append(x)
        return MySet(sub)
    
    def __and__(self, other):
        common = []
        for x in other:
            if x in self:
                common.append(x)
        return MySet(common)
    
    def __sub__(self, other):
        diff = []
        for x in self:
            if x not in other:
                diff.append(x)
        return MySet(diff)


    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)

    
if __name__ == "__main__":
    s = MySet([1, 2, 3, 4, 5, 6]) 
    print len(s) 

    print bool(s) 
 
    print 2 in s
# Out:
# 6
# True
# True

# %% [markdown]
# 따로 정의하지 않으면 class 객체에 내장되어 있는 함수가 수행되어서 위와 같은 결과가 출력된다.

# %% [markdown]
# ##7. 프로젝트 오일러 16
# 215 = 32768 의 각 자리수를 더하면 3 + 2 + 7 + 6 + 8 = 26 입니다.
#
# 21000의 각 자리수를 모두 더하면 얼마입니까?

# %%
num = 1<<1000

numlist = []

numstr = str(num)
for x in numstr:
    numlist.append(int(x))

print sum(numlist)
# Out:
# 1366

# %% [markdown]
# ##8. 프로젝트 오일러 17
# 1부터 5까지의 숫자를 영어로 쓰면 one, two, three, four, five 이고,
# 각 단어의 길이를 더하면 3 + 3 + 5 + 4 + 4 = 19 이므로 사용된 글자는 모두 19개입니다.
#
# 1부터 1,000까지 영어로 썼을 때는 모두 몇 개의 글자를 사용해야 할까요?
#
# 참고: 빈 칸이나 하이픈('-')은 셈에서 제외하며, 단어 사이의 and 는 셈에 넣습니다.
#    예를 들어 342를 영어로 쓰면 three hundred and forty-two 가 되어서 23 글자,
#    115 = one hundred and fifteen 의 경우에는 20 글자가 됩니다.

# %%
lens=[0,3,3,5,4,4,3,5,5,4,3,6,6,8,8,7,7,9,8,8,0,0,6,6,5,5,5,7,6,6,7,0]

t=11

for x in range(1,1000):
    d = x%100
    e = x//100
    f = d%10
    g = d//10
    if e>0:
        if d+f+g==0:
            t = t+lens[e]+lens[30]
        else:
            t = t+lens[e]+lens[30]+3
    if g>1:
        t = t+lens[g+20]+lens[f]
    else:
        t= t+lens[d]
print t
# Out:
# 21124

# %% [markdown]
# ##9. 프로젝트 오일러18
#
#
#
# 다음과 같이 삼각형 모양으로 숫자를 배열했습니다.
#
# 3
#
# 7 4
#
# 2 4 6
#
# 8 5 9 3
#
# 삼각형의 꼭대기부터 아래쪽으로 인접한 숫자를 찾아 내려가면서 합을 구하면, 위의 그림처럼 3 + 7 + 4 + 9 = 23 이 가장 큰 합을 갖는 경로가 됩니다.
#
# 다음 삼각형에서 합이 최대가 되는 경로를 찾아서 그 합을 구하세요.
#
# 75
#
# 95 64
#
# 17 47 82
#
# 18 35 87 10
#
# 20 04 82 47 65
#
# 19 01 23 75 03 34
#
# 88 02 77 73 07 63 67
#
# 99 65 04 28 06 16 70 92
#
# 41 41 26 56 83 40 80 70 33
#
# 41 48 72 33 47 32 37 16 94 29
#
# 53 71 44 65 25 43 91 52 97 51 14
#
# 70 11 33 28 77 73 17 78 39 68 17 57
#
# 91 71 52 38 17 14 91 43 58 50 27 29 48
#
# 63 66 04 68 89 53 67 30 73 16 69 87 40 31
#
# 04 62 98 27 23 09 70 98 73 93 38 53 60 04 23

# %%
triangle = [
 [75],
 [95, 64],
 [17, 47, 82],
 [18, 35, 87, 10],
 [20, 04, 82, 47, 65],
 [19, 01, 23, 75, 03, 34],
 [88, 02, 77, 73, 07, 63, 67],
 [99, 65, 04, 28, 06, 16, 70, 92],
 [41, 41, 26, 56, 83, 40, 80, 70, 33],
 [41, 48, 72, 33, 47, 32, 37, 16, 94, 29],
 [53, 71, 44, 65, 25, 43, 91, 52, 97, 51, 14],
 [70, 11, 33, 28, 77, 73, 17, 78, 39, 68, 17, 57],
 [91, 71, 52, 38, 17, 14, 91, 43, 58, 50, 27, 29, 48],
 [63, 66, 04, 68, 89, 53, 67, 30, 73, 16, 69, 87, 40, 31],
 [04, 62, 98, 27, 23, 9, 70, 98, 73, 93, 38, 53, 60, 04, 23]]
  
for a in range(len(triangle) - 1, -1, -1):
    for b in range(0, a):  
        triangle [a-1][b] += max(triangle [a][b], triangle [a][b+1])

        
print triangle [0][0]
# Out:
# 1074

# %% [markdown]
# ##10. 프로젝트 오일러19
# 다음은 달력에 관한 몇 가지 일반적인 정보입니다 (필요한 경우 좀 더 연구를 해 보셔도 좋습니다).
#
# •1900년 1월 1일은 월요일이다.
#
# •4월, 6월, 9월, 11월은 30일까지 있고, 1월, 3월, 5월, 7월, 8월, 10월, 12월은 31일까지 있다.
#
# •2월은 28일이지만, 윤년에는 29일까지 있다.
#
# •윤년은 연도를 4로 나누어 떨어지는 해를 말한다. 하지만 400으로 나누어 떨어지지 않는 매 100년째는 윤년이 아니며, 400으로 나누어 떨어지면 윤년이다
#
# 20세기 (1901년 1월 1일 ~ 2000년 12월 31일) 에서, 매월 1일이 일요일인 경우는 총 몇 번입니까?

# %%
def dayListBuild():
    dayListBuild = [[0,0,0]]
    for year in range(1900, 2001):
        for month in range(1, 13):
            if month in [4, 6, 9, 11]:
                dayRange = 30
            elif not month - 2:
                if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0):
                        dayRange = 29
                else:
                    dayRange = 28
            else:
                dayRange = 31
            for day in range(1, dayRange + 1):
                dayListBuild.append([year, month, day])
    return dayListBuild

def sundayList():
    dayList = dayListBuild()
    sundayList = []
    for day in range(len(dayList)):
        if not (day - 6) % 7 and dayList[day][0] > 1900 and not dayList[day][2] - 1:
            sundayList.append(dayList[day])
    return len(sundayList)

print(sundayList())
# Out:
# 171

# %% [markdown]
# ##11. 프로젝트 오일러20
# n! 이라는 표기법은 n × (n − 1) × ... × 3 × 2 × 1을 뜻합니다.
#
# 예를 들자면 10! = 10 × 9 × ... × 3 × 2 × 1 = 3628800 이 되는데,
# 여기서 10!의 각 자리수를 더해 보면 3 + 6 + 2 + 8 + 8 + 0 + 0 = 27 입니다.
#
# 100! 의 자리수를 모두 더하면 얼마입니까?

# %%
def myfact(n):
    if n == 0:
        return 1
    else:
        return n*myfact(n-1)
    
numlist = []

numstr = str(myfact(100))
for x in numstr:
    numlist.append(int(x))

print sum(numlist)
# Out:
# 648

# %% [markdown]
# ##12. 프로젝트 오일러21
# n의 약수들 중에서 자신을 제외한 것의 합을 d(n)으로 정의했을 때,
# 서로 다른 두 정수 a, b에 대하여 d(a) = b 이고 d(b) = a 이면
# a, b는 친화쌍이라 하고 a와 b를 각각 친화수(우애수)라고 합니다.
#
# 예를 들어 220의 약수는 자신을 제외하면 1, 2, 4, 5, 10, 11, 20, 22, 44, 55, 110 이므로 그 합은 d(220) = 284 입니다.
# 또 284의 약수는 자신을 제외하면 1, 2, 4, 71, 142 이므로 d(284) = 220 입니다.
# 따라서 220과 284는 친화쌍이 됩니다.
#
# 10000 이하의 친화수들을 모두 찾아서 그 합을 구하세요.

# %%
def d(n):
    the_sum = 0
    for i in range(1,n):
        if n%i == 0: the_sum += i
    return the_sum
 
total = 0
for i in range(1, 10000):
    x = d(i) 
    y = d(x)
    if i == y and i != x:
        total += i
print total
# Out:
# 31626

# %% [markdown]
# ##13. 이전 Assignment 3 (Assignment 4가 아님)의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하여 각 단어들에 대해 출현빈도를 사전형태({'world': 2, 'hello': 1, 'python': 1})로 저장하여 출력하는 것이었다. 이번에는 Assignment 3을 다시 확장/변형하여 다음과 같은 조건을 만족하도록 구현하시오.
# •1) 새로운 클래스 WebWordsFrequency를 정의하시오.◾이전 Assignment 4에서 고려했던 pickle 모듈등은 전혀 고려하지 마시오.
#
# ◾즉, 하드시스크에 저장하고 다시 로드하는 기능은 본 숙제에는 배제하시오.
#
# ◾Assignment 4에서 고려했던 영어 불용어 처리는 적용하시오.◦영어 불용어: [ 'a', 'and', 'are', 'as', 'at', 'be', 'but', 'by', 'for', 'if', 'in', 'into', 'is', 'it', 'no', 'not', 'of', 'on', 'or', 's', 'such', 't', 'that', 'the', 'their', 'then', 'there', 'these', 'they', 'this', 'to', 'was', 'will', 'with']
#
# ◾Assignment 4에서 처럼 국문 사이트가 아닌 영어 사이트만을 고려하여 아래 사항을 코딩하시오.
#
# •2) 생성자에 URL을 0개에서 임의의 개수를 넣을 수 있도록 생성자 인수를 가변인수로 정의하여 각각의 URL을 리스트 자료형에 유지하시오.
#
# w1 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com', 'https://www.amazon.com')
#
#  w2 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com')
#
#  w3 = WebWordsFrequency()
#
#
#
# •3) addUrl() 메소드를 구현하여 인스턴스를 생성한 이후에도 URL을 추가할 수 있도록 한다.
#
# ◾반드시 1개의 URL을 추가하도록 구현 (즉, 동시에 여러 개의 URL을 추가하는 것은 배제)
#
#
#  w1.addUrl('https://github.com')
#
#  w3.addUrl('http://stackoverflow.com')
#
# •4) removeUrl() 메소드를 구현하여 URL을 삭제할 수 있도록 한다.
#
# ◾반드시 1개의 URL을 삭제하도록 구현 (즉, 동시에 여러 개의 URL을 삭제하는 것은 배제)
#
#
# w1.removeUrl('http://www.cnn.com')
#
#  w2.removeUrl('http://stackoverflow.com')
#
#
# •5) listUrls() 메소드를 구현하여 현재 등록된 모든 URL을 출력하는 기능을 추가
#
#  w1.listUrls()
# http://www.times.com
# https://www.amazon.com
# https://github.com
#
#
#
# •6) getWordsFrequency() 메소드를 구현하여 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현 빈도 사전을 반환하시오.
#
# ◾만약 등록된 URL이 없다면 공백 사전을 반환
#
#
#  w1.getWordsFrequency()
#
#  {'hello': 8, 'site': 12, 'world': 2, 'science': 11, 'program': 1, 'python': 1}
#
#
# •7) getMaxFreqencyWords() 메소드를 구현하여 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현 빈도 사전에서 가장 많이 출현한 단어 리스트를 반환하시오.
#
#
#  w1.getMaxFreqencyWords()
#
#  site
#
# ◾최다 출현 단어의 빈도수가 동일한 경우 모두 출력해주어야 함
#
#
#  w2.getMaxFreqencyWords()
#
#  site
#  science
#
# ◾만약 등록된 URL이 없다면 None을 반환

# %%
import urllib2
import string

class WebWordsFrequency:
    urllist = []
    frequencywordlist = []
    def __init__(self,*url):
        if url == None:
            self.urllist.append(None)
        else:
            self.urllist = []
            for x in range(0,len(url)):
                self.urllist.append(url[x])

    def addUrl(self,url):
        if url in self.urllist:
            print "입력한 URL이 이미 등록되어 있습니다."
        else:
            self.urllist.append(url)
        
    def removeUrl(self,url):
        if url in self.urllist:
            for x in range(0,len(self.urllist)):
                if self.urllist[x] == url:
                    del self.urllist[x]
                    break
        else:
            print "입력한 URL이 등록되어 있지 않습니다."
            
    def listUrls(self):
        print self.urllist
    
    def getWords(self):
        u=0
        if self.urllist[0] == None:
            print {}
        while u<len(self.urllist):
            source = urllib2.urlopen(self.urllist[u]).read()            

            string1 = ''
            string2 = ''
            string3 = ''
            string4 = ''

            notuse = [ 'a', 'and', 'are', 'as', 'at', 'be', 'but', 'by', 'for',
          'if', 'in', 'into', 'is', 'it', 'no', 'not', 'of', 'on', 'or',
          's', 'such', 't', 'that', 'the', 'their', 'then', 'there', 
          'these', 'they', 'this', 'to', 'was', 'will', 'with']
            l = []
            r = []
            k = []
            p = []

            for line in source.splitlines():
                line = line.lstrip()
                for word in line:
                    if word == '<':
                        string1 += '\n'
                    string1 += word
                    if word == '>':
                        string1 += '\n'
            
            for line in string1.splitlines():
                line = line.lstrip()
                for word in line:
                    string2 += word
                l.append(string2)
                string2 = ''

            for x in range(0,len(l)):
                if l[x] != '':
                    r.append(l[x])
            
            for x in range(0,len(r)):
                if (r[x][0] == '<') or (r[x][0] == '/') or (r[x][0] == '-'):
                    r[x] = ''
        
            for x in range(0,len(r)):
                if r[x] != '':
                    k.append(r[x])
        
            for x in range(0,len(k)):
                string3 += k[x]
                string3 += ' '


            limit = len(string3)

            x = 0

            while x<limit:
                for y in range(0,len(string.punctuation)):
                    if string3[x] == string.punctuation[y]:
                        string3 = string3.replace(string3[x],'')
                        limit = len(string3)
                for y in range(0,len(notuse)):
                    if string3[x] == notuse[y]:
                        string3 = string3.replace(string3[x],'')
                        limit = len(string3)
                x += 1
    
            p = string3.split()
            words = {}
            frequency = {}

            for i in p:
                if not i in words.keys():
                    if len(i)<20 and len(i)>1: 
                        #너무길거나 짧은 이상한 외계단어들 삭제
                        words[i]=1
                else:
                    words[i]=words[i]+1
        
            for i in words:
                frequency[i] = words[i]
            
            
            frequencywords = frequency.items()
            frequencywords.sort(key=lambda(x,y):y,reverse=True)
        
            self.frequencywordlist.append(frequencywords[0][0])
            i=0
            while frequencywords[i][1] == frequencywords[i+1][1]:
                self.frequencywordlist.append(frequencywords[i+1][0])
                i+=1
            return frequency    
            u+=1
            
    def getWordsFrequency(self):
        for x in range(0,len(self.urllist)):
            print self.urllist[x]
            print self.getWords()
 
    def getMaxFreqencyWords(self):  
        print self.frequencywordlist

        
class OrderedWebWordsFrequency(WebWordsFrequency):
    urllist = []
    totalfrequencywords = {}
    frequencywords = []
    def __init__(self,*url):
        if url == None:
            self.urllist.append(None)
        else:
            self.urllist = []
            for x in range(0,len(url)):
                self.urllist.append(url[x])

    def getWordsFrequency(self, rvs=False):
        for x in range(0,len(self.urllist)):
            self.totalfrequencywords.update(WebWordsFrequency.getWords(self))
            
        self.frequencywords = self.totalfrequencywords.items()
        self.frequencywords.sort(key=lambda(x,y):y,reverse=rvs)
        print self.frequencywords

    def __iter__(self):
        self.data = 0
        return self
    def next(self):
        self.data +=1
        if self.data == len(self.frequencywords):
            raise StopIteration
        return self.frequencywords[self.data]
    
w1 = WebWordsFrequency('http://www.cnn.com','http://www.times.com')
w1.addUrl('https://github.com')
w1.removeUrl('http://www.cnn.com')
w1.getWordsFrequency()
w1.getMaxFreqencyWords()

w2 = OrderedWebWordsFrequency('http://www.times.com','https://github.com')
w2.getWordsFrequency()
w2.getWordsFrequency(rvs=True)

for x in w2:
    print x
# Out:
# http://www.times.com
# ...

# %% [markdown]
# ##Comment
# 과제를 하면서 기말고사 시험공부하는데 큰 도움이 되었습니다.
# 한학기 동안 고생 많으셨습니다!!
